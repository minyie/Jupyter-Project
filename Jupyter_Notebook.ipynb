# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Faith Abadi** <br> Data Analyst

# %% [markdown]
# *I am interested in data science because it shows me how I can use the information arround me in a new and powerful way.*

# %% [markdown]
# ### The code bellow is going to show a mathematics equation.

# %%
x = 9
y = 3
print (x * y)
# Out:
# 27

# %% [markdown]
# 1. Kevin is a boy.
# ---
# > this is a block quote
